# %% [markdown]
# # Lending Club Case Study
#
# --------
#
# ## Data Understanding

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
from plotly.offline import plot, iplot, init_notebook_mode
import plotly.graph_objs as go
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.read_csv("./loan.csv")

# %%
print(df.shape)
print(df.columns)
df.head()
# Out:
# (39717, 111)
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade',
#        ...
#        'num_tl_90g_dpd_24m', 'num_tl_op_past_12m', 'pct_tl_nvr_dlq',
#        'percent_bc_gt_75', 'pub_rec_bankruptcies', 'tax_liens',
#        'tot_hi_cred_lim', 'total_bal_ex_mort', 'total_bc_limit',
#        'total_il_high_credit_limit'],
#       dtype='object', length=111)
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#   int_rate  installment grade sub_grade  ... num_tl_90g_dpd_24m  \
# 0   10.65%       162.87     B        B2  ...                NaN
# 1   15.27%        59.83     C        C4  ...                NaN
# 2   15.96%        84.33     C        C5  ...                NaN
# 3   13.49%       339.31     C        C1  ...                NaN
# 4   12.69%        67.79     B        B5  ...                NaN
#
#   num_tl_op_past_12m pct_tl_nvr_dlq  percent_bc_gt_75 pub_rec_bankruptcies  \
# 0                NaN            NaN               NaN                  0.0
# 1                NaN            NaN               NaN                  0.0
# 2                NaN            NaN               NaN                  0.0
# 3                NaN            NaN               NaN                  0.0
# 4                NaN            NaN               NaN                  0.0
#
#   tax_liens tot_hi_cred_lim total_bal_ex_mort total_bc_limit  \
# 0       0.0             NaN               NaN            NaN
# 1       0.0             NaN               NaN            NaN
# 2       0.0             NaN               NaN            NaN
# 3       0.0             NaN               NaN            NaN
# 4       0.0             NaN               NaN            NaN
#
#   total_il_high_credit_limit
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
#
# [5 rows x 111 columns]

# %%
df.describe().transpose()
# Out:
#                               count           mean            std      min  \
# id                          39717.0  683131.913060  210694.132915  54734.0
# member_id                   39717.0  850463.559408  265678.307421  70699.0
# loan_amnt                   39717.0   11219.443815    7456.670694    500.0
# funded_amnt                 39717.0   10947.713196    7187.238670    500.0
# funded_amnt_inv             39717.0   10397.448868    7128.450439      0.0
# ...                             ...            ...            ...      ...
# tax_liens                   39678.0       0.000000       0.000000      0.0
# tot_hi_cred_lim                 0.0            NaN            NaN      NaN
# total_bal_ex_mort               0.0            NaN            NaN      NaN
# total_bc_limit                  0.0            NaN            NaN      NaN
# total_il_high_credit_limit      0.0            NaN            NaN      NaN
#
#                                  25%       50%        75%        max
# id                          516221.0  665665.0   837755.0  1077501.0
# member_id                   666780.0  850812.0  1047339.0  1314167.0
# loan_amnt                     5500.0   10000.0    15000.0    35000.0
# funded_amnt                   5400.0    9600.0    15000.0    35000.0
# funded_amnt_inv               5000.0    8975.0    14400.0    35000.0
# ...                              ...       ...        ...        ...
# tax_liens                        0.0       0.0        0.0        0.0
# tot_hi_cred_lim                  NaN       NaN        NaN        NaN
# total_bal_ex_mort                NaN       NaN        NaN        NaN
# total_bc_limit                   NaN       NaN        NaN        NaN
# total_il_high_credit_limit       NaN       NaN        NaN        NaN
#
# [87 rows x 8 columns]

# %%
df.isna().sum()
# Out:
# id                                0
# member_id                         0
# loan_amnt                         0
# funded_amnt                       0
# funded_amnt_inv                   0
#                               ...
# tax_liens                        39
# tot_hi_cred_lim               39717
# total_bal_ex_mort             39717
# total_bc_limit                39717
# total_il_high_credit_limit    39717
# Length: 111, dtype: int64

# %% [markdown]
# ## Data Cleaning
#
#     [a] Exclude columns which has more than 50% nulls
#     [b] Remove Unnecessary columns / Duplcate columns which can be dervided from existing columns
#     [c] Fill all the Null columns with Mean/ Mode/ Median as per the data

# %% [markdown]
# ##### [a] Identify & exclude columns which has more than 50% nulls

# %%
# identify columns which has more than 90% nulls
col_na = pd.DataFrame(df.isna().sum(), columns = ["count"])
print(0.1*len(df))
col_na1 = col_na[col_na["count"] >= 0.5*len(df)]
col_na1
# Out:
# 3971.7000000000003
#                                 count
# mths_since_last_delinq          25682
# mths_since_last_record          36931
# next_pymnt_d                    38577
# mths_since_last_major_derog     39717
# annual_inc_joint                39717
# dti_joint                       39717
# verification_status_joint       39717
# tot_coll_amt                    39717
# tot_cur_bal                     39717
# open_acc_6m                     39717
# open_il_6m                      39717
# open_il_12m                     39717
# open_il_24m                     39717
# mths_since_rcnt_il              39717
# total_bal_il                    39717
# il_util                         39717
# open_rv_12m                     39717
# open_rv_24m                     39717
# max_bal_bc                      39717
# all_util                        39717
# total_rev_hi_lim                39717
# inq_fi                          39717
# total_cu_tl                     39717
# inq_last_12m                    39717
# acc_open_past_24mths            39717
# avg_cur_bal                     39717
# bc_open_to_buy                  39717
# bc_util                         39717
# mo_sin_old_il_acct              39717
# mo_sin_old_rev_tl_op            39717
# mo_sin_rcnt_rev_tl_op           39717
# mo_sin_rcnt_tl                  39717
# mort_acc                        39717
# mths_since_recent_bc            39717
# mths_since_recent_bc_dlq        39717
# mths_since_recent_inq           39717
# mths_since_recent_revol_delinq  39717
# num_accts_ever_120_pd           39717
# num_actv_bc_tl                  39717
# num_actv_rev_tl                 39717
# num_bc_sats                     39717
# num_bc_tl                       39717
# num_il_tl                       39717
# num_op_rev_tl                   39717
# num_rev_accts                   39717
# num_rev_tl_bal_gt_0             39717
# num_sats                        39717
# num_tl_120dpd_2m                39717
# num_tl_30dpd                    39717
# num_tl_90g_dpd_24m              39717
# num_tl_op_past_12m              39717
# pct_tl_nvr_dlq                  39717
# percent_bc_gt_75                39717
# tot_hi_cred_lim                 39717
# total_bal_ex_mort               39717
# total_bc_limit                  39717
# total_il_high_credit_limit      39717

# %%
col_na["count"].min(),col_na["count"].max()
# Out:
# (0, 39717)

# %%
col_na1["count"].min(),col_na1["count"].max()
# Out:
# (25682, 39717)

# %%
col_na1.index
# Out:
# Index(['mths_since_last_delinq', 'mths_since_last_record', 'next_pymnt_d',
#        'mths_since_last_major_derog', 'annual_inc_joint', 'dti_joint',
#        'verification_status_joint', 'tot_coll_amt', 'tot_cur_bal',
#        'open_acc_6m', 'open_il_6m', 'open_il_12m', 'open_il_24m',
#        'mths_since_rcnt_il', 'total_bal_il', 'il_util', 'open_rv_12m',
#        'open_rv_24m', 'max_bal_bc', 'all_util', 'total_rev_hi_lim', 'inq_fi',
#        'total_cu_tl', 'inq_last_12m', 'acc_open_past_24mths', 'avg_cur_bal',
#        'bc_open_to_buy', 'bc_util', 'mo_sin_old_il_acct',
#        'mo_sin_old_rev_tl_op', 'mo_sin_rcnt_rev_tl_op', 'mo_sin_rcnt_tl',
#        'mort_acc', 'mths_since_recent_bc', 'mths_since_recent_bc_dlq',
#        'mths_since_recent_inq', 'mths_since_recent_revol_delinq',
#        'num_accts_ever_120_pd', 'num_actv_bc_tl', 'num_actv_rev_tl',
#        'num_bc_sats', 'num_bc_tl', 'num_il_tl', 'num_op_rev_tl',
#        'num_rev_accts', 'num_rev_tl_bal_gt_0', 'num_sats', 'num_tl_120dpd_2m',
#        'num_tl_30dpd', 'num_tl_90g_dpd_24m', 'num_tl_op_past_12m',
#        'pct_tl_nvr_dlq', 'percent_bc_gt_75', 'tot_hi_cred_lim',
#        'total_bal_ex_mort', 'total_bc_limit', 'total_il_high_credit_limit'],
#       dtype='object')

# %% [markdown]
# ##### [b] Identify & exclude columns with only 1 distinct value

# %%
# Identify columns with 1 unique value
col_uni = pd.DataFrame(df.nunique(), columns = ["count"])
# print(0.1*len(df1))
col_uni1 = col_uni[col_uni["count"] == 1]
col_uni1
# Out:
#                             count
# pymnt_plan                      1
# initial_list_status             1
# collections_12_mths_ex_med      1
# policy_code                     1
# application_type                1
# acc_now_delinq                  1
# chargeoff_within_12_mths        1
# delinq_amnt                     1
# tax_liens                       1

# %%
len(set(df.columns) - set(col_na1.index) - set(col_uni1.index))
# Out:
# 45

# %%
# [x for x in df.columns if x not in set(col_na1.index)]

# %%
df1 = df[list(set(df.columns) - set(col_na1.index) - set(col_uni1.index))]
df1.head()
# Out:
#    installment  pub_rec home_ownership  total_acc addr_state zip_code  \
# 0       162.87        0           RENT          9         AZ    860xx
# 1        59.83        0           RENT          4         GA    309xx
# 2        84.33        0           RENT         10         IL    606xx
# 3       339.31        0           RENT         37         CA    917xx
# 4        67.79        0           RENT         38         OR    972xx
#
#                   title issue_d last_pymnt_d    dti  ...       id  \
# 0              Computer  Dec-11       Jan-15  27.65  ...  1077501
# 1                  bike  Dec-11       Apr-13   1.00  ...  1077430
# 2  real estate business  Dec-11       Jun-14   8.72  ...  1077175
# 3              personel  Dec-11       Jan-15  20.00  ...  1076863
# 4              Personal  Dec-11       May-16  17.94  ...  1075358
#
#   verification_status                                               desc  \
# 0            Verified    Borrower added on 12/22/11 > I need to upgra...
# 1     Source Verified    Borrower added on 12/22/11 > I plan to use t...
# 2        Not Verified                                                NaN
# 3     Source Verified    Borrower added on 12/21/11 > to pay for prop...
# 4     Source Verified    Borrower added on 12/21/11 > I plan on combi...
#
#    int_rate  funded_amnt                                                url  \
# 0    10.65%         5000  https://lendingclub.com/browse/loanDetail.acti...
# 1    15.27%         2500  https://lendingclub.com/browse/loanDetail.acti...
# 2    15.96%         2400  https://lendingclub.com/browse/loanDetail.acti...
# 3    13.49%        10000  https://lendingclub.com/browse/loanDetail.acti...
# 4    12.69%         3000  https://lendingclub.com/browse/loanDetail.acti...
#
#    sub_grade out_prncp_inv total_rec_late_fee  delinq_2yrs
# 0         B2          0.00               0.00            0
# 1         C4          0.00               0.00            0
# 2         C5          0.00               0.00            0
# 3         C1          0.00              16.97            0
# 4         B5        524.06               0.00            0
#
# [5 rows x 45 columns]

# %%
df1.isna().sum()
# Out:
# installment                    0
# pub_rec                        0
# home_ownership                 0
# total_acc                      0
# addr_state                     0
# zip_code                       0
# title                         11
# issue_d                        0
# last_pymnt_d                  71
# dti                            0
# emp_length                  1075
# last_credit_pull_d             2
# member_id                      0
# total_pymnt_inv                0
# total_rec_int                  0
# inq_last_6mths                 0
# recoveries                     0
# loan_status                    0
# emp_title                   2459
# loan_amnt                      0
# last_pymnt_amnt                0
# purpose                        0
# total_pymnt                    0
# pub_rec_bankruptcies         697
# revol_util                    50
# out_prncp                      0
# revol_bal                      0
# collection_recovery_fee        0
# grade                          0
# annual_inc                     0
# funded_amnt_inv                0
# total_rec_prncp                0
# earliest_cr_line               0
# open_acc                       0
# term                           0
# id                             0
# verification_status            0
# desc                       12940
# int_rate                       0
# funded_amnt                    0
# url                            0
# sub_grade                      0
# out_prncp_inv                  0
# total_rec_late_fee             0
# delinq_2yrs                    0
# dtype: int64

# %%
df1.emp_length.unique()
# Out:
# array(['10+ years', '< 1 year', '1 year', '3 years', '8 years', '9 years',
#        '4 years', '5 years', '6 years', '2 years', '7 years', nan],
#       dtype=object)

# %%
# import plotly.express as px
# data = df1
# fig = px.histogram(data, x="emp_length")
# fig.show()

# %% [markdown]
# ##### [c] Identify & fill all the Null columns with Mean/ Mode/ Median as per the data

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# histogram
# display(sns.histplot(data = df1.emp_length, kde = True))
# display(sns.histplot(data = df1.emp_title, kde = True))
sns.histplot(data = df1.emp_length, kde = True)
# Out:
# <AxesSubplot:xlabel='emp_length', ylabel='Count'>

# %%
# import plotly.express as px
# data = df1
# fig = px.histogram(data, x="emp_title")
# fig.show()

# %%
# sns.histplot(data = df1.emp_title, kde = True)

# %%
df_test = pd.DataFrame(df1[["id","emp_title"]].groupby("emp_title")["id"].count())
df_test.sort_values(by="id",ascending = False)
# Out:
#                                     id
# emp_title
# US Army                            134
# Bank of America                    109
# IBM                                 66
# AT&T                                59
# Kaiser Permanente                   56
# ...                                ...
# Hartford Financial Services Group    1
# Hartford Board of Education          1
# Harte Hanks                          1
# Hart  and  Cooley                    1
# zozaya officiating                   1
#
# [28820 rows x 1 columns]

# %%
# import plotly.express as px
# data = df1
# fig = px.histogram(data, x="revol_util")
# fig.show()

# %%
sns.histplot(data = df1.revol_util, kde = True)
# Out:
# <AxesSubplot:xlabel='revol_util', ylabel='Count'>

# %%
df1["revol_util"] = df1["revol_util"].str.replace("%","").astype(float)
df1["revol_util"].mode(), df1["revol_util"].mean()
# Out:
# (0    0.0
#  Name: revol_util, dtype: float64,
#  48.83215241888721)

# %%
# filling Nulls with the most occuring category (Mode) or mean or unknown if 
#          the frequency of the values in a column is low
# filling with Mode
fill_na_cols_mode = ["emp_length", "last_pymnt_d", "title", "pub_rec_bankruptcies", "last_credit_pull_d"]
for i in fill_na_cols_mode:
    print("Mode " + i + " " + str(df1[i].mode()[0]))
    df1[i] = df1[i].fillna(value=df1[i].mode()[0])

# filling with Mean
fill_na_cols_mean = ["revol_util" ]
for i in fill_na_cols_mean:
    print("Mean" + i + " " + str(df1[i].mean()))
    df1[i] = df1[i].fillna(value=df1[i].mean())

# filling with Unknown
finn_na_unknown = ["emp_title"]
for i in finn_na_unknown:
    print("Unknown " + i)
    df1[i] = df1[i].fillna(value="Unknown")
    
df1.isna().sum()
# Out:
# Mode emp_length 10+ years
# Mode last_pymnt_d May-16
# Mode title Debt Consolidation
# Mode pub_rec_bankruptcies 0.0
# Mode last_credit_pull_d May-16
# Meanrevol_util 48.83215241888721
# Unknown emp_title
# installment                    0
# pub_rec                        0
# home_ownership                 0
# total_acc                      0
# addr_state                     0
# zip_code                       0
# title                          0
# issue_d                        0
# last_pymnt_d                   0
# dti                            0
# emp_length                     0
# last_credit_pull_d             0
# member_id                      0
# total_pymnt_inv                0
# total_rec_int                  0
# inq_last_6mths                 0
# recoveries                     0
# loan_status                    0
# emp_title                      0
# loan_amnt                      0
# last_pymnt_amnt                0
# purpose                        0
# total_pymnt                    0
# pub_rec_bankruptcies           0
# revol_util                     0
# out_prncp                      0
# revol_bal                      0
# collection_recovery_fee        0
# grade                          0
# annual_inc                     0
# funded_amnt_inv                0
# total_rec_prncp                0
# earliest_cr_line               0
# open_acc                       0
# term                           0
# id                             0
# verification_status            0
# desc                       12940
# int_rate                       0
# funded_amnt                    0
# url                            0
# sub_grade                      0
# out_prncp_inv                  0
# total_rec_late_fee             0
# delinq_2yrs                    0
# dtype: int64

# %%
print(df1.url[0])
# df1["url"].str.replace("https://lendingclub.com/browse/loanDetail.action\?loan_id="," ")
df1[df1.url.str.replace("https://lendingclub.com/browse/loanDetail.action\?loan_id=","").astype(int)!=df1.id.astype(int)]
# Out:
# https://lendingclub.com/browse/loanDetail.action?loan_id=1077501
# Empty DataFrame
# Columns: [installment, pub_rec, home_ownership, total_acc, addr_state, zip_code, title, issue_d, last_pymnt_d, dti, emp_length, last_credit_pull_d, member_id, total_pymnt_inv, total_rec_int, inq_last_6mths, recoveries, loan_status, emp_title, loan_amnt, last_pymnt_amnt, purpose, total_pymnt, pub_rec_bankruptcies, revol_util, out_prncp, revol_bal, collection_recovery_fee, grade, annual_inc, funded_amnt_inv, total_rec_prncp, earliest_cr_line, open_acc, term, id, verification_status, desc, int_rate, funded_amnt, url, sub_grade, out_prncp_inv, total_rec_late_fee, delinq_2yrs]
# Index: []
#
# [0 rows x 45 columns]

# %%
# Removing the columns which are not required or duplucate columns which can be derived from other columns
cols = ["desc","url"]
for i in cols:
    try:
        del df1[i]
    except:
        print("{0} not found".format(i))
        
df1.head()
# Out:
#    installment  pub_rec home_ownership  total_acc addr_state zip_code  \
# 0       162.87        0           RENT          9         AZ    860xx
# 1        59.83        0           RENT          4         GA    309xx
# 2        84.33        0           RENT         10         IL    606xx
# 3       339.31        0           RENT         37         CA    917xx
# 4        67.79        0           RENT         38         OR    972xx
#
#                   title issue_d last_pymnt_d    dti  ... open_acc        term  \
# 0              Computer  Dec-11       Jan-15  27.65  ...        3   36 months
# 1                  bike  Dec-11       Apr-13   1.00  ...        3   60 months
# 2  real estate business  Dec-11       Jun-14   8.72  ...        2   36 months
# 3              personel  Dec-11       Jan-15  20.00  ...       10   36 months
# 4              Personal  Dec-11       May-16  17.94  ...       15   60 months
#
#         id  verification_status  int_rate  funded_amnt  sub_grade  \
# 0  1077501             Verified    10.65%         5000         B2
# 1  1077430      Source Verified    15.27%         2500         C4
# 2  1077175         Not Verified    15.96%         2400         C5
# 3  1076863      Source Verified    13.49%        10000         C1
# 4  1075358      Source Verified    12.69%         3000         B5
#
#   out_prncp_inv total_rec_late_fee  delinq_2yrs
# 0          0.00               0.00            0
# 1          0.00               0.00            0
# 2          0.00               0.00            0
# 3          0.00              16.97            0
# 4        524.06               0.00            0
#
# [5 rows x 43 columns]

# %%
df1.isna().sum()
# Out:
# installment                0
# pub_rec                    0
# home_ownership             0
# total_acc                  0
# addr_state                 0
# zip_code                   0
# title                      0
# issue_d                    0
# last_pymnt_d               0
# dti                        0
# emp_length                 0
# last_credit_pull_d         0
# member_id                  0
# total_pymnt_inv            0
# total_rec_int              0
# inq_last_6mths             0
# recoveries                 0
# loan_status                0
# emp_title                  0
# loan_amnt                  0
# last_pymnt_amnt            0
# purpose                    0
# total_pymnt                0
# pub_rec_bankruptcies       0
# revol_util                 0
# out_prncp                  0
# revol_bal                  0
# collection_recovery_fee    0
# grade                      0
# annual_inc                 0
# funded_amnt_inv            0
# total_rec_prncp            0
# earliest_cr_line           0
# open_acc                   0
# term                       0
# id                         0
# verification_status        0
# int_rate                   0
# funded_amnt                0
# sub_grade                  0
# out_prncp_inv              0
# total_rec_late_fee         0
# delinq_2yrs                0
# dtype: int64

# %%
df1.to_excel("Cleaned-Loan-data.xlsx")

# %%
df1=df1[df1.loan_status !='Current']

# %% [markdown]
# ## Univariate Analysis

# %%
# checking for any categorical variable with distinct count same as # of rows, This is to exclude the column from analysis
df1.nunique()
# Out:
# installment                14928
# pub_rec                        5
# home_ownership                 5
# total_acc                     82
# addr_state                    50
# zip_code                     822
# title                      19134
# issue_d                       55
# last_pymnt_d                 101
# dti                         2853
# emp_length                    11
# last_credit_pull_d           106
# member_id                  38193
# total_pymnt_inv            36025
# total_rec_int              33702
# inq_last_6mths                 9
# recoveries                  4011
# loan_status                    2
# emp_title                  27794
# loan_amnt                    867
# last_pymnt_amnt            34086
# purpose                       14
# total_pymnt                36349
# pub_rec_bankruptcies           3
# revol_util                  1088
# out_prncp                      1
# revol_bal                  21054
# collection_recovery_fee     2597
# grade                          7
# annual_inc                  5064
# funded_amnt_inv             7956
# total_rec_prncp             6788
# earliest_cr_line             524
# open_acc                      40
# term                           2
# id                         38193
# verification_status            3
# desc                       25547
# int_rate                     370
# funded_amnt                 1013
# url                        38193
# sub_grade                     35
# out_prncp_inv                  1
# total_rec_late_fee          1307
# delinq_2yrs                   11
# int_rate_percent             370
# dtype: int64

# %%
df1.loan_status.unique()
# Out:
# array(['Fully Paid', 'Charged Off'], dtype=object)

# %%
len(df1.title.unique())
# Out:
# 19135

# %%
len(df1.zip_code.unique())
# Out:
# 822

# %%
len(df1.addr_state.unique())
# Out:
# 50

# %%
len(df1.home_ownership.unique())
# Out:
# 5

# %%
len(df1.last_credit_pull_d.unique())
# Out:
# 107

# %%
len(df1.emp_title.unique())
# Out:
# 27795

# %%
df1.issue_d.head()
# Out:
# 0    Dec-11
# 1    Dec-11
# 2    Dec-11
# 3    Dec-11
# 5    Dec-11
# Name: issue_d, dtype: object

# %%
# df1["year"] = df.issue_d.str.split('-')[1]
# df1["month"] = df.issue_d.str.split('-')[0]
df1[["month", "year",]] = df.issue_d.str.split('-', expand = True)
df1[["year","month"]].head()
# Out:
#   year month
# 0   11   Dec
# 1   11   Dec
# 2   11   Dec
# 3   11   Dec
# 5   11   Dec

# %%
plt.figure(figsize=(15,4))
plt.subplot(1,2,1)
sns.countplot(x='year', data=df1.sort_values("grade"))
plt.subplot(1,2,2)
sns.countplot(x='month', data=df1)
plt.show()

# %%
plt.figure(figsize=(30,4))
# plt.subplot(1,2,1)
sns.countplot(x='issue_d', data=df1)
plt.xticks(rotation=90)
plt.show()

# %%
sns.boxplot(x="loan_status", y="loan_amnt", data=df1)
# Out:
# <AxesSubplot:xlabel='loan_status', ylabel='loan_amnt'>

# %%
sns.boxplot( y=df1["loan_amnt"] )
# Out:
# <AxesSubplot:ylabel='loan_amnt'>

# %% [markdown]
# **Inference**: The loan amount varies from ~0 to ~35,000 & have a mean of 10,000

# %%
df1["loan_status"].value_counts()
# Out:
# Fully Paid     32609
# Charged Off     5584
# Name: loan_status, dtype: int64

# %%
sns.countplot(x='grade', data=df1.sort_values("grade"))
# Out:
# <AxesSubplot:xlabel='grade', ylabel='count'>

# %% [markdown]
# **Inference**: Most of the loans are high graded loans which have grade of A and B (> 50%).

# %%
sns.countplot(x='emp_length', data = df1)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **Inference**: Most of the loans are taken by employees with more than 10 years exp (~25%).

# %%
sns.boxplot(x=df1['annual_inc'])
# Out:
# <AxesSubplot:xlabel='annual_inc'>

# %%
## Removing outliers in annual_inc greater than 99th percentile
df1 = df1[df1.annual_inc<=np.percentile(df1.annual_inc,99)]

# %%
sns.boxplot(x=df1['annual_inc'])
# Out:
# <AxesSubplot:xlabel='annual_inc'>

# %%
df1['annual_inc'].describe().transpose()
# Out:
# count     37812.000000
# mean      63899.375600
# std       32324.944139
# min        4000.000000
# 25%       40000.000000
# 50%       57600.000000
# 75%       80000.000000
# max      189000.000000
# Name: annual_inc, dtype: float64

# %% [markdown]
# **Inference**: Average loan amount is ~64,000/- with a Standard deviation of 32,000/-

# %% [markdown]
# ## Segmented Univariate Analysis

# %%
# sns.countplot(hue='loan_status',x="annual_inc", data=df1)
sns.boxplot(y='annual_inc', x='loan_status', data=df1)
# Out:
# <AxesSubplot:xlabel='loan_status', ylabel='annual_inc'>

# %%
sns.countplot(hue='loan_status',x="grade", data=df1.sort_values("grade"))
# Out:
# <AxesSubplot:xlabel='grade', ylabel='count'>

# %% [markdown]
# **Inference**: Most the charged off lies in A, B & D grades. Looking in percentage perspoective, Grade D has **High Risk**

# %%
sns.countplot(x='loan_status',hue="grade", data=df1.sort_values("grade"))
# Out:
# <AxesSubplot:xlabel='loan_status', ylabel='count'>

# %%
a = df1.groupby(["grade",])["id"].count()
b = df1.groupby(["grade","loan_status"])["id"].count().reset_index()
c = pd.merge(b,a,how="left", on="grade")
c["loan_per"] = 100* c.id_x/c.id_y
pd.pivot_table(c, values='loan_per', index=["grade",],
                    columns=["loan_status"], aggfunc=np.sum)
# Out:
# loan_status  Charged Off  Fully Paid
# grade
# A               6.055713   93.944287
# B              12.259867   87.740133
# C              17.430954   82.569046
# D              22.202130   77.797870
# E              27.015504   72.984496
# F              32.941176   67.058824
# G              34.154930   65.845070

# %% [markdown]
# **Inference**: Grade A (~25% cases) is on of the lagest grade consuming loans yet is has compatively Charged off cases.
#   - Grade A cases are **Lowest Risk**
#   - Grade F & G has **Highest Risk**
#   - Charged Off (risk) rate increase from Grade A to G

# %%
sns.countplot(x='emp_length',hue="loan_status", data=df1)
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(hue='emp_length',x="loan_status", data=df1)
# Out:
# <AxesSubplot:xlabel='loan_status', ylabel='count'>

# %%
# sns.boxplot(y='annual_inc', x='loan_status', data=df1)
plt.figure(figsize=(15,4))
plt.subplot(1,2,1)
sns.countplot(x="loan_status", hue="year", data=df1)
plt.subplot(1,2,2)
sns.countplot(x="loan_status", hue="month", data=df1)
plt.show()

# %%
a = df1.groupby(["year",])["id"].count()
b = df1.groupby(["year","loan_status"])["id"].count().reset_index()
c = pd.merge(b,a,how="left", on="year")
c["loan_per"] = 100* c.id_x/c.id_y
pd.pivot_table(c, values='loan_per', index=["year",],
                    columns=["loan_status"], aggfunc=np.sum)
# Out:
# loan_status  Charged Off  Fully Paid
# year
# 07             17.500000   82.500000
# 08             15.864759   84.135241
# 09             12.657130   87.342870
# 10             12.855628   87.144372
# 11             16.038205   83.961795

# %%
df1["int_rate_percent"] = df1['int_rate'].str.rstrip('%').astype(float)

# %%
sns.boxplot(y='int_rate_percent', x='loan_status', data=df1)
# Out:
# <AxesSubplot:xlabel='loan_status', ylabel='int_rate_percent'>

# %%
sns.countplot(x='purpose', hue="loan_status", data=df1)
plt.xticks(rotation=90)
plt.show()

# %%
a = df1.groupby(["purpose",])["id"].count()
b = df1.groupby(["purpose","loan_status"])["id"].count().reset_index()
c = pd.merge(b,a,how="left", on="purpose")
c["loan_per"] = 100* c.id_x/c.id_y
pd.pivot_table(c, values='loan_per', index=["purpose",],
                    columns=["loan_status"], aggfunc=np.sum)
# Out:
# loan_status         Charged Off   Current  Fully Paid
# purpose
# car                   10.376135  3.242542   86.381323
# credit_card           10.552171  2.004323   87.443506
# debt_consolidation    14.878088  3.135644   81.986268
# educational           17.027864       NaN   82.972136
# home_improvement      11.679337  3.351762   84.968901
# house                 15.633423  3.773585   80.592992
# major_purchase        10.156971  1.708218   88.134811
# medical               15.451895  1.749271   82.798834
# moving                15.771231  1.213172   83.015598
# other                 15.891865  3.183426   80.924709
# renewable_energy      18.811881  0.990099   80.198020
# small_business        26.265999  4.117974   69.616027
# vacation              13.910761  1.574803   84.514436
# wedding               10.032017  2.134472   87.833511

# %% [markdown]
# **Inference**: small_business, renewable_energy & educational loans are top 3 loans which has the most charged_off cases. **High Risk**

# %%
sns.boxplot(y='int_rate_percent', x='purpose', data=df1)
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(x='home_ownership',hue='loan_status', data=df1)
# Out:
# <AxesSubplot:xlabel='home_ownership', ylabel='count'>

# %%
a = df1.groupby(["home_ownership",])["id"].count()
b = df1.groupby(["home_ownership","loan_status"])["id"].count().reset_index()
c = pd.merge(b,a,how="left", on="home_ownership")
c["loan_per"] = 100* c.id_x/c.id_y
pd.pivot_table(c, values='loan_per', index=["home_ownership",],
                    columns=["loan_status"], aggfunc=np.sum)
# Out:
# loan_status     Charged Off   Current  Fully Paid
# home_ownership
# MORTGAGE          13.246634  3.613765   83.139602
# NONE                    NaN       NaN  100.000000
# OTHER             18.750000       NaN   81.250000
# OWN               14.526246  2.707164   82.766590
# RENT              15.010897  2.211237   82.777866

# %%
sns.countplot( x="term", hue='loan_status', data=df1)
plt.xticks(rotation=90)
plt.show()

# %%
a = df1.groupby(["term",])["id"].count()
b = df1.groupby(["term","loan_status"])["id"].count().reset_index()
c = pd.merge(b,a,how="left", on="term")
c["loan_per"] = 100* c.id_x/c.id_y
pd.pivot_table(c, values='loan_per', index=["term",],
                    columns=["loan_status"], aggfunc=np.sum)
# Out:
# loan_status  Charged Off    Current  Fully Paid
# term
#  36 months      11.10687        NaN   88.893130
#  60 months      22.69740  10.724831   66.577769

# %% [markdown]
# **Inference**: Most of the loans (~75%) are 36 month tenured but the remaining ~25% loans which have 60 months tenure has ~22% (of 25%) Charged Off cases

# %%
sns.countplot( x="loan_status", hue="pub_rec_bankruptcies", data=df1)
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(data=df1,x='delinq_2yrs',hue='loan_status')
# Out:
# <AxesSubplot:xlabel='delinq_2yrs', ylabel='count'>

# %%
sns.boxplot(x='loan_status',y='open_acc',data=df1)
# Out:
# <AxesSubplot:xlabel='loan_status', ylabel='open_acc'>

# %%
df1["revol_util"] = df1.revol_util.str.strip("%").astype(float)

# %%
sns.boxplot(x='loan_status',y='revol_util',data=df1)
# Out:
# <AxesSubplot:xlabel='loan_status', ylabel='revol_util'>

# %%
sns.boxplot(x='loan_status',y='total_acc',data=df1)
# Out:
# <AxesSubplot:xlabel='loan_status', ylabel='total_acc'>

# %%
sns.boxplot(x='loan_status',y='total_rec_prncp',data=df1)
# Out:
# <AxesSubplot:xlabel='loan_status', ylabel='total_rec_prncp'>

# %%
plt.figure(figsize=(15,4))
sns.countplot(x='addr_state', hue='loan_status', data=df1)
# Out:
# <AxesSubplot:xlabel='addr_state', ylabel='count'>

# %%
a = df1.groupby(["addr_state",])["id"].count()
b = df1.groupby(["addr_state","loan_status"])["id"].count().reset_index()
c = pd.merge(b,a,how="left", on="addr_state")
c["loan_per"] = 100* c.id_x/c.id_y
d = pd.pivot_table(c, values='loan_per', index=["addr_state",],
                    columns=["loan_status"], aggfunc=np.sum)
pd.merge(d,a,how="left", on="addr_state").sort_values("id", ascending = False)
# Out:
#             Charged Off  Fully Paid    id
# addr_state
# CA            16.272580   83.727420  6809
# NY            13.503751   86.496249  3599
# FL            18.168498   81.831502  2730
# TX            11.825886   88.174114  2596
# NJ            15.850144   84.149856  1735
# PA            12.284334   87.715666  1449
# IL            13.453537   86.546463  1442
# VA            13.085502   86.914498  1345
# GA            16.005984   83.994016  1337
# MA            12.171838   87.828162  1257
# OH            13.036021   86.963979  1166
# MD            16.000000   84.000000  1000
# AZ            14.405762   85.594238   833
# WA            15.756824   84.243176   806
# CO            12.898936   87.101064   752
# NC            15.468114   84.531886   737
# CT            13.486370   86.513630   697
# MI            14.634146   85.365854   697
# MO            17.194570   82.805430   663
# MN            13.522538   86.477462   599
# NV            22.410148   77.589852   473
# SC            14.541387   85.458613   447
# OR            16.359447   83.640553   434
# AL            12.500000   87.500000   432
# WI            14.351852   85.648148   432
# LA            12.500000   87.500000   416
# KY            14.469453   85.530547   311
# OK            14.084507   85.915493   284
# KS            12.350598   87.649402   251
# UT            15.789474   84.210526   247
# AR            11.353712   88.646288   229
# DC             7.177033   92.822967   209
# RI            12.698413   87.301587   189
# NM            16.759777   83.240223   179
# WV            12.209302   87.790698   172
# HI            16.867470   83.132530   166
# NH            15.337423   84.662577   163
# DE            10.810811   89.189189   111
# MT            13.253012   86.746988    83
# WY             5.000000   95.000000    80
# AK            18.421053   81.578947    76
# SD            19.354839   80.645161    62
# VT            11.320755   88.679245    53
# MS            10.526316   89.473684    19
# TN            11.764706   88.235294    17
# IN                  NaN  100.000000     9
# ID            16.666667   83.333333     6
# NE            60.000000   40.000000     5
# IA                  NaN  100.000000     5
# ME                  NaN  100.000000     3

# %% [markdown]
# **Inference**: All the top States have almost similar Charged Off rate

# %% [markdown]
# ## Bivariate Analysis

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df1.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(y='int_rate_percent', x='grade', data=df1.sort_values("grade"))
# Out:
# <AxesSubplot:xlabel='grade', ylabel='int_rate_percent'>

# %% [markdown]
# **Inference**: Intrest Rate Increase from Grade A to G, which is in parity with the increase in Charged off rate

# %%
sns.barplot(y='annual_inc', x='pub_rec_bankruptcies', data=df1)
plt.xticks(rotation=90)
plt.show()

# %%
sns.boxplot(x="home_ownership", y="loan_amnt", data=data)
# Out:
# <AxesSubplot:xlabel='home_ownership', ylabel='loan_amnt'>
